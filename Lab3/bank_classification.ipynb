# %% [markdown]
# <a href="https://colab.research.google.com/github/PreethamThinagaraj/CE888/blob/main/Lab3/bank_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("https://raw.githubusercontent.com/albanda/CE888/master/lab3/bank-additional-full.csv", delimiter = ";")

# %%
df
# Out:
#        age          job  marital  ... euribor3m nr.employed    y
# 0       56    housemaid  married  ...     4.857      5191.0   no
# 1       57     services  married  ...     4.857      5191.0   no
# 2       37     services  married  ...     4.857      5191.0   no
# 3       40       admin.  married  ...     4.857      5191.0   no
# 4       56     services  married  ...     4.857      5191.0   no
# ...    ...          ...      ...  ...       ...         ...  ...
# 41183   73      retired  married  ...     1.028      4963.6  yes
# 41184   46  blue-collar  married  ...     1.028      4963.6   no
# 41185   56      retired  married  ...     1.028      4963.6   no
# 41186   44   technician  married  ...     1.028      4963.6  yes
# 41187   74      retired  married  ...     1.028      4963.6   no
#
# [41188 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                   int64
# dtype: object

# %%
# convert a string variable to a categorical one
df[["y"]] = df[["y"]].apply(LabelEncoder().fit_transform)

# %%
df
# Out:
#        age          job  marital  ... euribor3m nr.employed  y
# 0       56    housemaid  married  ...     4.857      5191.0  0
# 1       57     services  married  ...     4.857      5191.0  0
# 2       37     services  married  ...     4.857      5191.0  0
# 3       40       admin.  married  ...     4.857      5191.0  0
# 4       56     services  married  ...     4.857      5191.0  0
# ...    ...          ...      ...  ...       ...         ... ..
# 41183   73      retired  married  ...     1.028      4963.6  1
# 41184   46  blue-collar  married  ...     1.028      4963.6  0
# 41185   56      retired  married  ...     1.028      4963.6  0
# 41186   44   technician  married  ...     1.028      4963.6  1
# 41187   74      retired  married  ...     1.028      4963.6  0
#
# [41188 rows x 21 columns]

# %%
df_dummies = pd.get_dummies(df)

# %%
df_dummies
# Out:
#        age  duration  ...  poutcome_nonexistent  poutcome_success
# 0       56       261  ...                     1                 0
# 1       57       149  ...                     1                 0
# 2       37       226  ...                     1                 0
# 3       40       151  ...                     1                 0
# 4       56       307  ...                     1                 0
# ...    ...       ...  ...                   ...               ...
# 41183   73       334  ...                     1                 0
# 41184   46       383  ...                     1                 0
# 41185   56       189  ...                     1                 0
# 41186   44       442  ...                     1                 0
# 41187   74       239  ...                     0                 0
#
# [41188 rows x 64 columns]

# %%
df_dummies.columns
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'y',
#        'job_admin.', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
#        'marital_divorced', 'marital_married', 'marital_single',
#        'marital_unknown', 'education_basic.4y', 'education_basic.6y',
#        'education_basic.9y', 'education_high.school', 'education_illiterate',
#        'education_professional.course', 'education_university.degree',
#        'education_unknown', 'default_no', 'default_unknown', 'default_yes',
#        'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
#        'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone',
#        'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun',
#        'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
#        'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu',
#        'day_of_week_tue', 'day_of_week_wed', 'poutcome_failure',
#        'poutcome_nonexistent', 'poutcome_success'],
#       dtype='object')

# %%
new_df=df_dummies.drop("duration",axis=1)

# %%
new_df
# Out:
#        age  campaign  ...  poutcome_nonexistent  poutcome_success
# 0       56         1  ...                     1                 0
# 1       57         1  ...                     1                 0
# 2       37         1  ...                     1                 0
# 3       40         1  ...                     1                 0
# 4       56         1  ...                     1                 0
# ...    ...       ...  ...                   ...               ...
# 41183   73         1  ...                     1                 0
# 41184   46         1  ...                     1                 0
# 41185   56         2  ...                     1                 0
# 41186   44         1  ...                     1                 0
# 41187   74         3  ...                     0                 0
#
# [41188 rows x 63 columns]

# %%
pd.set_option('max_rows', 99999)
pd.set_option('max_colwidth', 400)
pd.describe_option('max_colwidth')
# Out:
# display.max_colwidth : int or None
#     The maximum width in characters of a column in the repr of
#     a pandas data structure. When the column overflows, a "..."
#     placeholder is embedded in the output. A 'None' value means unlimited.
#     [default: 50] [currently: 400]

# %%
new_df.isnull().sum()
# Out:
# age                              0
# campaign                         0
# pdays                            0
# previous                         0
# emp.var.rate                     0
# cons.price.idx                   0
# cons.conf.idx                    0
# euribor3m                        0
# nr.employed                      0
# y                                0
# job_admin.                       0
# job_blue-collar                  0
# job_entrepreneur                 0
# job_housemaid                    0
# job_management                   0
# job_retired                      0
# job_self-employed                0
# job_services                     0
# job_student                      0
# job_technician                   0
# job_unemployed                   0
# job_unknown                      0
# marital_divorced                 0
# marital_married                  0
# marital_single                   0
# marital_unknown                  0
# education_basic.4y               0
# education_basic.6y               0
# education_basic.9y               0
# education_high.school            0
# education_illiterate             0
# education_professional.course    0
# education_university.degree      0
# education_unknown                0
# default_no                       0
# default_unknown                  0
# default_yes                      0
# housing_no                       0
# housing_unknown                  0
# housing_yes                      0
# loan_no                          0
# loan_unknown                     0
# loan_yes                         0
# contact_cellular                 0
# contact_telephone                0
# month_apr                        0
# month_aug                        0
# month_dec                        0
# month_jul                        0
# month_jun                        0
# month_mar                        0
# month_may                        0
# month_nov                        0
# month_oct                        0
# month_sep                        0
# day_of_week_fri                  0
# day_of_week_mon                  0
# day_of_week_thu                  0
# day_of_week_tue                  0
# day_of_week_wed                  0
# poutcome_failure                 0
# poutcome_nonexistent             0
# poutcome_success                 0
# dtype: int64

# %%
new_df.shape
# Out:
# (41188, 63)

# %%
sns_plot = sns.histplot(new_df['y'])

# %%
g = sns.countplot(new_df['y'])
g.set_xticklabels(['No','Yes'])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# print percentage of questions where target == 1
(len(new_df.loc[df.y==1])) / (len(new_df.loc[df.y == 0])) * 100
# Out:
# 12.6956331399803

# %%
(len(new_df.loc[df.y==1]))/ (len(df['y'])) * 100
# Out:
# 11.265417111780131

# %%
#dropped columns as part of feature selection
X = new_df.drop(['y'],axis=1)
#storing the target variable in Y
y = new_df.y

# %%
X.head()
# Out:
#    age  campaign  ...  poutcome_nonexistent  poutcome_success
# 0   56         1  ...                     1                 0
# 1   57         1  ...                     1                 0
# 2   37         1  ...                     1                 0
# 3   40         1  ...                     1                 0
# 4   56         1  ...                     1                 0
#
# [5 rows x 62 columns]

# %%
X.columns
# Out:
# Index(['age', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
#        'job_admin.', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
#        'marital_divorced', 'marital_married', 'marital_single',
#        'marital_unknown', 'education_basic.4y', 'education_basic.6y',
#        'education_basic.9y', 'education_high.school', 'education_illiterate',
#        'education_professional.course', 'education_university.degree',
#        'education_unknown', 'default_no', 'default_unknown', 'default_yes',
#        'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
#        'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone',
#        'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun',
#        'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
#        'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu',
#        'day_of_week_tue', 'day_of_week_wed', 'poutcome_failure',
#        'poutcome_nonexistent', 'poutcome_success'],
#       dtype='object')

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: y, dtype: int64

# %% [markdown]
# From the plot above, we can see we have a very imbalanced classification - just 12.69% of our dataset belong to the target class yes!

# %%
# split imbalanced dataset into train and test sets with stratification
from collections import Counter
from sklearn.model_selection import train_test_split
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=50, stratify=y)
print(Counter(y_train))
print(Counter(y_test))
# Out:
# Counter({0: 29238, 1: 3712})
# Counter({0: 7310, 1: 928})

# %%
from sklearn.ensemble import RandomForestClassifier
# Create Decision Tree classifer object
rf = RandomForestClassifier(n_estimators= 100,max_depth= 3)
#rf = RandomForestClassifier(n_estimators= 200,max_depth= 8)

# %%
#rf = RandomForestClassifier(n_estimators= 100,max_depth= 12,random_state=60)

# %%
rf.fit(X_train, y_train)
y_pred=rf.predict(X_test)
#Generaing accuracy score to check the performance of the model
f1_score(y_test, y_pred)
# Out:
# 0.33278955954323

# %%
#from sklearn.model_selection import StratifiedKFold 
#from sklearn import model_selection
from sklearn.model_selection import cross_val_score, cross_val_predict
# Create StratifiedKFold object. 
#skfold = StratifiedKFold(n_splits=10)
#model_skfold = LogisticRegression()
results_skfold = cross_val_score(rf, X_train, y_train, cv=10,scoring='f1')
print(results_skfold)
print("Accuracy: %.2f%%" % (results_skfold.mean()*100.0))
# Out:
# [0.20861678 0.26067416 0.20642202 0.24886878 0.20547945 0.27616927
#  0.33688699 0.22624434 0.25560538 0.24669604]
# Accuracy: 24.72%

# %%
from sklearn.dummy import DummyClassifier
#from sklearn.metrics import accuracy_score as acc
from sklearn.metrics import f1_score
dummy_clf = DummyClassifier(strategy='stratified')
dummy_clf.fit(X_train, y_train)
y_pred=dummy_clf.predict(X_test)
print("Dummy ACC: %.2f" % f1_score(y_test, y_pred))
#print("Dummy ACC: %.2f" % f1_score(y_test, y_pred,average='macro'))
#print("Dummy ACC: %.2f" % f1_score(y_test, y_pred,average='micro'))
# Out:
# Dummy ACC: 0.11

# %%
results_skfold = cross_val_score(dummy_clf, X_train, y_train, cv=10,scoring='f1')
print(results_skfold)
print("Accuracy: %.2f%%" % (results_skfold.mean()*100.0))
# Out:
# [0.10928962 0.10320781 0.11032532 0.0945758  0.08481532 0.11382114
#  0.10714286 0.10810811 0.09973046 0.11126961]
# Accuracy: 10.42%

# %%
#grid search for tuning the parameters
from sklearn.model_selection import GridSearchCV
#n_estimators = [int(x) for x in np.linspace(start = 100, stop = 700, num = 50)] # randomly generating 50 numbers from 100 to 700
#max_features = ['auto']  # Number of features to consider at every split
#max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]   # Maximum number of levels in tree
#max_depth.append(None)
# defining parameter range
param_grid = { 
    'n_estimators': [50,100,150,200,250,300,350,400],
    #'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [10,20,30,40],
    'criterion' :['gini', 'entropy']
}

# %%
#fitting the model
rf.fit(X_train, y_train)
#grid search for tuning the parameters
CV_rfc = GridSearchCV(estimator=rf, param_grid=param_grid,scoring='f1', cv= 10)
CV_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=3,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 20, 30, 40],
#                          'n_estimators': [50, 100, 150, 200, 250, 300, 350,
#                                           400]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1_weighted', verbose=0)

# %%
CV_rfc.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 20, 'n_estimators': 150}

# %%
# Create Decision Tree classifer object
rf = RandomForestClassifier(n_estimators= 150,max_depth= 20,criterion='entropy')

# %%
results_skfold = model_selection.cross_val_score(rf, X_train, y_train, cv=10,scoring="f1")
print(results_skfold)
print("Accuracy: %.2f%%" % (results_skfold.mean()*100.0))
# Out:
# [0.87956784 0.89189715 0.8818365  0.87812481 0.87044725 0.88324147
#  0.89364647 0.8751099  0.88255248 0.87488222]
# Accuracy: 88.11%

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=12, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=60, verbose=0,
#                        warm_start=False)

# %%
features =['age', 'campaign', 'pdays', 'previous', 'emp.var.rate',
       'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
       'job_admin.', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
       'job_management', 'job_retired', 'job_self-employed', 'job_services',
       'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
       'marital_divorced', 'marital_married', 'marital_single',
       'marital_unknown', 'education_basic.4y', 'education_basic.6y',
       'education_basic.9y', 'education_high.school', 'education_illiterate',
       'education_professional.course', 'education_university.degree',
       'education_unknown', 'default_no', 'default_unknown', 'default_yes',
       'housing_no', 'housing_unknown', 'housing_yes', 'loan_no',
       'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone',
       'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun',
       'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
       'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu',
       'day_of_week_tue', 'day_of_week_wed', 'poutcome_failure',
       'poutcome_nonexistent', 'poutcome_success']

# %%
importances = rf.feature_importances_
std = np.std([tree.feature_importances_ for tree in rf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]
print(indices)

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. %s (%f)" % (f + 1, features[indices[f]],  importances[indices[f]]))

# Plot the feature importances of the forest
fig = plt.figure()
plt.figure(figsize=(20,10))
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), np.array(features)[indices])
plt.xlim([-1, X.shape[1]])
plt.ylim([0, None])

fig.set_size_inches(15, 8)
# Out:
# [ 7  8 61  4  2  0  6  5  3  1 59 49 43 52 60 42 50 55 31 38 36 56 23 44
#  54 39 57 28 58 10 22  9 41 18 14 33 30 27 17 48 25 21 13 34 53 32 16 26
#  19 15 45 51 47 40 12 11 37 20 46 24 29 35]
# Feature ranking:
# 1. euribor3m (0.148393)
# 2. nr.employed (0.113660)
# 3. poutcome_success (0.076603)
# 4. emp.var.rate (0.065022)
# 5. pdays (0.061397)
# 6. age (0.060275)
# 7. cons.conf.idx (0.052059)
# 8. cons.price.idx (0.048685)
# 9. previous (0.029007)
# 10. campaign (0.026818)
# 11. poutcome_failure (0.016507)
# 12. month_mar (0.013838)
# 13. contact_telephone (0.013198)
# 14. month_oct (0.012439)
# 15. poutcome_nonexistent (0.012053)
# 16. contact_cellular (0.011745)
# 17. month_may (0.011076)
# 18. day_of_week_mon (0.010003)
# 19. education_university.degree (0.008650)
# 20. housing_yes (0.008404)
# 21. housing_no (0.008335)
# 22. day_of_week_thu (0.008108)
# 23. marital_single (0.008034)
# 24. month_apr (0.007734)
# 25. day_of_week_fri (0.007704)
# 26. loan_no (0.007311)
# 27. day_of_week_tue (0.007209)
# 28. education_high.school (0.007132)
# 29. day_of_week_wed (0.007122)
# 30. job_blue-collar (0.007086)
# 31. marital_married (0.006979)
# 32. job_admin. (0.006658)
# 33. loan_yes (0.006314)
# 34. job_technician (0.006138)
# 35. job_retired (0.006136)
# 36. default_no (0.005655)
# 37. education_professional.course (0.005636)
# 38. education_basic.9y (0.005475)
# 39. job_student (0.005337)
# 40. month_jun (0.005025)
# 41. education_basic.4y (0.005012)
# 42. marital_divorced (0.005011)
# 43. job_management (0.004365)
# 44. default_unknown (0.004250)
# 45. month_sep (0.004144)
# 46. education_unknown (0.003967)
# 47. job_services (0.003812)
# 48. education_basic.6y (0.003710)
# 49. job_unemployed (0.003344)
# 50. job_self-employed (0.003225)
# 51. month_aug (0.003192)
# 52. month_nov (0.003157)
# 53. month_jul (0.002885)
# 54. loan_unknown (0.002691)
# 55. job_housemaid (0.002682)
# 56. job_entrepreneur (0.002257)
# 57. housing_unknown (0.002240)
# 58. job_unknown (0.002103)
# 59. month_dec (0.001891)
# 60. marital_unknown (0.000849)
# 61. education_illiterate (0.000255)
# 62. default_yes (0.000000)

# %%
y_pred=rf.predict(X_test)
#Generaing accuracy score to check the performance of the model
f1_score(y_test, y_pred)
# Out:
# 0.37337413925019125
